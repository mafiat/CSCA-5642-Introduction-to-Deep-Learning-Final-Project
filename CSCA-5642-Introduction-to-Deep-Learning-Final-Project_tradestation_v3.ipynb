# %% [markdown]
# <div style="background-color: #013a63; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     CSCA 5642 - Introduction to Deep Learning - Final Project
# </div>

# %% [markdown]
# <div style="background-color: magenta; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Stock Market Price Pridiction and Direction Prediction
# </div>

# %% [markdown]
# #### Project Overview: Stock Market Prediction using Deep Learning
#
# This project aims to predict stock market price movements using deep learning techniques. We will focus on predicting the future price of a stock.
#
# Here is a breakdown of the steps involved in this notebook:
#
# **1. Data Collection:**
# *   **Source:** We fetch up to 10 years of historical daily stock data using the **Tradestation API**.
# *   **Features:** The dataset includes Open, High, Low, Close prices, and Volume (OHLCV).
# *   **Target:** We will analyze **SPY** (S&P 500 ETF) and **NVDA** (NVIDIA Corp).
#
# **2. Data Preprocessing and Feature Engineering:**
# *   **Data Cleaning:** Handle missing values and rows with zero volume.
# *   **Feature Scaling:** Normalize the features to a range of (0, 1) using `MinMaxScaler`, which is essential for stable training of neural networks.
# *   **Technical Indicators:** Engineer new features from the OHLCV data to provide more context to the model. The indicators created are:
#     *   Simple Moving Averages (SMA)
#     *   Relative Strength Index (RSI)
#     *   Moving Average Convergence Divergence (MACD)
#     *   Bollinger Bands
# *   **Sequence Creation:** The time-series data is transformed into sequences. We use a look-back period of 90 days of data to predict the next day's closing price.
#
# **3. Model Selection:**
# *   **LSTM (Long Short-Term Memory):** We use an LSTM network, a type of Recurrent Neural Network (RNN) well-suited for time-series forecasting due to its ability to capture long-term dependencies in data.
#
# **4. Model Training:**
# *   **Data Splitting:** The data is split chronologically into an 80% training set and a 20% testing set.
# *   **Model Architecture:** The LSTM model consists of multiple LSTM layers with `Dropout` for regularization, followed by `Dense` layers to produce a single output value for the price prediction.
# *   **Compilation:**
#     *   **Loss Function:** We use `Mean Squared Error (MSE)` as the loss function, which is standard for regression tasks like price prediction.
#     *   **Optimizer:** The `Adam` optimizer is used to train the model.
# *   **Training:** The model is trained for a set number of epochs, with performance monitored on a validation set.
#
# **5. Model Evaluation:**
# *   **Price Prediction Metrics:** The model's performance is evaluated on the unseen test set using **Root Mean Squared Error (RMSE)**.
# *   **Visualization:** We plot the predicted prices against the actual prices to visually assess how well the model's predictions align with the real market data.
#
# **6. Conclusion and Future Work:**
# *   Summarize the model's performance based on the evaluation metrics.
# *   Discuss potential improvements, such as:
#     *   Hyperparameter tuning (e.g., LSTM units, learning rate).
#     *   Experimenting with different model architectures (e.g., GRU, Transformers).
#     *   Incorporating external data like market sentiment from financial news.

# %% [markdown]
# <div style="background-color: purple; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Dataset Description - Tradestation Datafeed
# </div>

# %% [markdown]
# Tradestation is a well-established trading platform that offers a comprehensive API for accessing historical and real-time market data. The Tradestation API is a powerful tool for traders and developers who require high-quality data for analysis and algorithmic trading.
#
# ### Key Features of Tradestation's Datafeed:
#
# *   **Extensive Historical Data:** Tradestation provides deep historical data for a wide range of securities, including stocks and ETFs. In this project, we fetch up to 10 years of daily data.
# *   **Broad Coverage:** The API covers major U.S. equities, allowing us to analyze stocks like **NVIDIA (NVDA)** and ETFs like **SPY**.
# *   **Data Format (OHLCV):** The data is delivered in the standard OHLCV format:
#     *   **Open:** The opening price for the specified interval.
#     *   **High:** The highest price during the interval.
#     *   **Low:** The lowest price during the interval.
#     *   **Close:** The closing price at the end of the interval.
#     *   **TotalVolume:** The total number of shares traded.
# *   **Flexible Timeframes:** The API supports various timeframes, from minutes to daily, weekly, and monthly bars. This notebook uses the `daily` timeframe.
# *   **Authentication:** Access to the API is secured through OAuth 2.0, requiring a `CLIENT_ID`, `CLIENT_SECRET`, and a `REFRESH_TOKEN` to generate access tokens.
#
# ### Example: SPY vs. NVDA
#
# *   **SPY (SPDR S&P 500 ETF Trust):** This ETF tracks the S&P 500 index, representing the performance of 500 of the largest U.S. companies. It is often used as a benchmark for the overall market.
# *   **NVDA (NVIDIA Corporation):** A leading technology company known for its GPUs. As a single stock, its price is influenced by company-specific factors as well as broader market trends, making it more volatile than a diversified index like SPY.
#
# Using the Tradestation API, we can fetch and analyze the historical performance of both a broad market index (SPY) and a high-growth individual stock (NVDA) to build and test our predictive models.

# %% [markdown]
# <div style="background-color: purple; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Install Dependencies
# </div>

# %%
# !pip install alpaca-trade-api python-dotenv pandas numpy matplotlib scikit-learn tensorflow pandas_ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting alpaca-trade-api
#   Downloading alpaca_trade_api-3.2.0-py3-none-any.whl.metadata (29 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting pandas
#   Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting pandas_ta
#   Downloading pandas_ta-0.4.71b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting requests<3,>2 (from alpaca-trade-api)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Collecting websocket-client<2,>=0.56.0 (from alpaca-trade-api)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api)
#   Downloading websockets-10.4.tar.gz (84 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting msgpack==1.0.3 (from alpaca-trade-api)
#   Downloading msgpack-1.0.3.tar.gz (123 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting aiohttp<4,>=3.8.3 (from alpaca-trade-api)
#   Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting PyYAML==6.0.1 (from alpaca-trade-api)
#   Downloading PyYAML-6.0.1.tar.gz (125 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting deprecation==2.1.0 (from alpaca-trade-api)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in c:\users\afiat_trading\appdata\roaming\python\python313\site-packages (from deprecation==2.1.0->alpaca-trade-api) (25.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4,>=3.8.3->alpaca-trade-api)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4,>=3.8.3->alpaca-trade-api)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4,>=3.8.3->alpaca-trade-api)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4,>=3.8.3->alpaca-trade-api)
#   Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4,>=3.8.3->alpaca-trade-api)
#   Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4,>=3.8.3->alpaca-trade-api)
#   Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4,>=3.8.3->alpaca-trade-api)
#   Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>2->alpaca-trade-api)
#   Downloading charset_normalizer-3.4.3-cp313-cp313-win_amd64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>2->alpaca-trade-api)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>2->alpaca-trade-api)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\afiat_trading\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.2-cp313-cp313-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.4-py3-none-any.whl.metadata (5.0 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting setuptools (from tensorflow)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\afiat_trading\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting typing_extensions>=3.6.6 (from tensorflow)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.17.3-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.74.0-cp313-cp313-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.3-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting numba==0.61.2 (from pandas_ta)
#   Downloading numba-0.61.2-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Collecting tqdm>=4.67.1 (from pandas_ta)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->pandas_ta)
#   Downloading llvmlite-0.44.0-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Collecting numpy
#   Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.17.0-cp313-cp313-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: colorama in c:\users\afiat_trading\appdata\roaming\python\python313\site-packages (from tqdm>=4.67.1->pandas_ta) (0.4.6)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\afiat_trading\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading alpaca_trade_api-3.2.0-py3-none-any.whl (34 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl (45 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp313-cp313-win_amd64.whl (107 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.0 MB 8.6 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 10.3 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 13.7 MB/s  0:00:00
# Downloading matplotlib-3.10.6-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------------ --------------- 5.0/8.1 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 26.1 MB/s  0:00:00
# Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------- ----- 7.6/8.7 MB 36.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 36.9 MB/s  0:00:00
# Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#     --------------------------------------- 6.6/332.0 MB 33.3 MB/s eta 0:00:10
#    - -------------------------------------- 13.1/332.0 MB 32.2 MB/s eta 0:00:10
#    -- ------------------------------------- 22.5/332.0 MB 37.0 MB/s eta 0:00:09
#    --- ------------------------------------ 31.7/332.0 MB 39.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 45.1/332.0 MB 43.9 MB/s eta 0:00:07
#    ------ --------------------------------- 56.9/332.0 MB 46.2 MB/s eta 0:00:06
#    -------- ------------------------------- 69.5/332.0 MB 48.5 MB/s eta 0:00:06
#    --------- ------------------------------ 81.8/332.0 MB 50.1 MB/s eta 0:00:05
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading fonttools-4.59.2-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 54.8 MB/s  0:00:00
# Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 50.4 MB/s  0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading keras-3.11.3-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 53.6 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ---------------- ----------------------- 11.0/26.4 MB 57.1 MB/s eta 0:00:01
#    ------------------------------------ --- 23.9/26.4 MB 58.7 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 59.6 MB/s  0:00:00
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 55.1 MB/s  0:00:00
# Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl (40 kB)
# Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading pyparsing-3.2.4-py3-none-any.whl (113 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ------------ --------------------------- 11.8/38.5 MB 58.2 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/38.5 MB 59.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.5 MB 58.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 58.5 MB/s  0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 40.4 MB/s  0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl (15 kB)
# Downloading wrapt-1.17.3-cp313-cp313-win_amd64.whl (38 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp313-cp313-win_amd64.whl (316 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: msgpack, PyYAML, websockets
#   Building wheel for msgpack (pyproject.toml): started
#   Building wheel for msgpack (pyproject.toml): finished with status 'done'
#   Created wheel for msgpack: filename=msgpack-1.0.3-cp313-cp313-win_amd64.whl size=15815 sha256=db3fae1fc48d867a052d9ef73d0f8c8294c1d9e2a816379c6028746bb86bbfc4
#   Stored in directory: C:\Users\Afiat_Trading\AppData\Local\Temp\pip-ephem-wheel-cache-qus9ys98\wheels\35\fa\14\d8be957d182ae6702082fc85f93bb705f26723c831079c6862
#   Building wheel for PyYAML (pyproject.toml): started
#   Building wheel for PyYAML (pyproject.toml): finished with status 'done'
#   Created wheel for PyYAML: filename=pyyaml-6.0.1-cp313-cp313-win_amd64.whl size=45473 sha256=cf32fec97575ee2385b784cbeda709ec2be801c59289bb98100dd3931095912a
#   Stored in directory: C:\Users\Afiat_Trading\AppData\Local\Temp\pip-ephem-wheel-cache-qus9ys98\wheels\9c\9e\34\1e1548811b63a9d001469f21797e8b7d5c216d8eb928e7d6ad
#   Building wheel for websockets (pyproject.toml): started
#   Building wheel for websockets (pyproject.toml): finished with status 'done'
#   Created wheel for websockets: filename=websockets-10.4-cp313-cp313-win_amd64.whl size=95113 sha256=ac514593f5c12bb9edd7449bfdb5c40119d2b56b4dab822633026053129db42d
#   Stored in directory: C:\Users\Afiat_Trading\AppData\Local\Temp\pip-ephem-wheel-cache-qus9ys98\wheels\f5\dd\43\5b7132085406a982d2e0dd808f0ffed137865c8a8c5c7a5e4b
# Successfully built msgpack PyYAML websockets
# Installing collected packages: pytz, namex, msgpack, libclang, flatbuffers, wrapt, wheel, websockets, websocket-client, urllib3, tzdata, typing_extensions, tqdm, threadpoolctl, termcolor, tensorboard-data-server, setuptools, PyYAML, python-dotenv, pyparsing, protobuf, propcache, pillow, opt_einsum, numpy, multidict, mdurl, MarkupSafe, markdown, llvmlite, kiwisolver, joblib, idna, grpcio, google_pasta, gast, frozenlist, fonttools, deprecation, cycler, charset_normalizer, certifi, attrs, aiohappyeyeballs, absl-py, yarl, werkzeug, scipy, requests, pandas, optree, numba, ml_dtypes, markdown-it-py, h5py, contourpy, astunparse, aiosignal, tensorboard, scikit-learn, rich, pandas_ta, matplotlib, aiohttp, keras, alpaca-trade-api, tensorflow
#
#    ----------------------------------------  0/67 [pytz]
#    - --------------------------------------  2/67 [msgpack]
#    - --------------------------------------  3/67 [libclang]
#    -- -------------------------------------  4/67 [flatbuffers]
#    --- ------------------------------------  6/67 [wheel]
#    --- ------------------------------------  6/67 [wheel]
#    ---- -----------------------------------  7/67 [websockets]
#    ---- -----------------------------------  8/67 [websocket-client]
#    ----- ----------------------------------  9/67 [urllib3]
#    ----- ----------------------------------  9/67 [urllib3]
#    ----- ---------------------------------- 10/67 [tzdata]
#    ----- ---------------------------------- 10/67 [tzdata]
#    ------- -------------------------------- 12/67 [tqdm]
#    ------- -------------------------------- 12/67 [tqdm]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    --------- ------------------------------ 16/67 [setuptools]
#    ---------- ----------------------------- 17/67 [PyYAML]
#    ----------- ---------------------------- 19/67 [pyparsing]
#    ----------- ---------------------------- 20/67 [protobuf]
#    ----------- ---------------------------- 20/67 [protobuf]
#    ----------- ---------------------------- 20/67 [protobuf]
#    ----------- ---------------------------- 20/67 [protobuf]
#    ------------- -------------------------- 22/67 [pillow]
#    ------------- -------------------------- 22/67 [pillow]
#    ------------- -------------------------- 22/67 [pillow]
#    ------------- -------------------------- 22/67 [pillow]
#    ------------- -------------------------- 22/67 [pillow]
#    ------------- -------------------------- 23/67 [opt_einsum]
#    ------------- -------------------------- 23/67 [opt_einsum]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    -------------- ------------------------- 24/67 [numpy]
#    --------------- ------------------------ 26/67 [mdurl]
#    ---------------- ----------------------- 28/67 [markdown]
#    ---------------- ----------------------- 28/67 [markdown]
#    ----------------- ---------------------- 29/67 [llvmlite]
#    ----------------- ---------------------- 29/67 [llvmlite]
#    ----------------- ---------------------- 29/67 [llvmlite]
#    ----------------- ---------------------- 29/67 [llvmlite]
#    ------------------ --------------------- 31/67 [joblib]
#    ------------------ --------------------- 31/67 [joblib]
#    ------------------ --------------------- 31/67 [joblib]
#    ------------------ --------------------- 31/67 [joblib]
#    ------------------- -------------------- 33/67 [grpcio]
#    ------------------- -------------------- 33/67 [grpcio]
#    ------------------- -------------------- 33/67 [grpcio]
#    -------------------- ------------------- 34/67 [google_pasta]
#    -------------------- ------------------- 35/67 [gast]
#    ---------------------- ----------------- 37/67 [fonttools]
#    ---------------------- ----------------- 37/67 [fonttools]
#    ---------------------- ----------------- 37/67 [fonttools]
#    ---------------------- ----------------- 37/67 [fonttools]
#    ----------------------------------- ---- 59/67 [scikit-learn]
#    ----------------------------------- ---- 59/67 [scikit-learn]
#    ----------------------------------- ---- 59/67 [scikit-learn]
#    ----------------------------------- ---- 59/67 [scikit-learn]
#    ----------------------------------- ---- 59/67 [scikit-learn]
#    ----------------------------------- ---- 60/67 [rich]
#    ----------------------------------- ---- 60/67 [rich]
#    ----------------------------------- ---- 60/67 [rich]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------ --- 61/67 [pandas_ta]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 62/67 [matplotlib]
#    ------------------------------------- -- 63/67 [aiohttp]
#    ------------------------------------- -- 63/67 [aiohttp]
#    ------------------------------------- -- 63/67 [aiohttp]
#    ------------------------------------- -- 63/67 [aiohttp]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 64/67 [keras]
#    -------------------------------------- - 65/67 [alpaca-trade-api]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------  66/67 [tensorflow]
#    ---------------------------------------- 67/67 [tensorflow]
#
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.1 absl-py-2.3.1 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 alpaca-trade-api-3.2.0 astunparse-1.6.3 attrs-25.3.0 certifi-2025.8.3 charset_normalizer-3.4.3 contourpy-1.3.3 cycler-0.12.1 deprecation-2.1.0 flatbuffers-25.2.10 fonttools-4.59.2 frozenlist-1.7.0 gast-0.6.0 google_pasta-0.2.0 grpcio-1.74.0 h5py-3.14.0 idna-3.10 joblib-1.5.2 keras-3.11.3 kiwisolver-1.4.9 libclang-18.1.1 llvmlite-0.44.0 markdown-3.9 markdown-it-py-4.0.0 matplotlib-3.10.6 mdurl-0.1.2 ml_dtypes-0.5.3 msgpack-1.0.3 multidict-6.6.4 namex-0.1.0 numba-0.61.2 numpy-2.2.6 opt_einsum-3.4.0 optree-0.17.0 pandas-2.3.2 pandas_ta-0.4.71b0 pillow-11.3.0 propcache-0.3.2 protobuf-6.32.1 pyparsing-3.2.4 python-dotenv-1.1.1 pytz-2025.2 requests-2.32.5 rich-14.1.0 scikit-learn-1.7.2 scipy-1.16.2 setuptools-80.9.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.1.0 threadpoolctl-3.6.0 tqdm-4.67.1 typing_extensions-4.15.0 tzdata-2025.2 urllib3-1.26.20 websocket-client-1.8.0 websockets-10.4 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.3 yarl-1.20.1

# %% [markdown]
# <div style="background-color: purple; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Libraries
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import time, timedelta, datetime
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler

import pandas as pd
import os
from dotenv import load_dotenv


import sys

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from urllib.parse import urlparse, parse_qs

# Load environment variables from .env file
load_dotenv()


import requests
import json


#import pandas_ta as ta

# %% [markdown]
# <div style="background-color: purple; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Mount Google Drive for Colab - Optional and only if using Colab
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %% [markdown]
# <div style="background-color: purple; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Loading the Dataset and Inspection
# </div>

# %% [markdown]
# 1. Credentials

# %%
# authentication requires your API credentials
CLIENT_ID = 'qnEIw9sTwkIUpKKmB19D2ZvgPRFomBfR'
CLIENT_SECRET = 'BtKH4wraTdsEQidx5sNQJwzRsWiS5yg9Q-CONT3Q_ewq-mixnPnVDDk1HiVX148b'

#API_BASE_URL = "https://api.tradestation.com/v3/marketdata"
API_BASE_URL = "https://api.tradestation.com/v3"

# Set the stock symbol and prediction parameters
SYMBOL = "SPY"       # The stock symbol you want to analyze  
TIMEFRAME = "daily"  # The timeframe for the historical data (e.g., 'minute', 'daily', 'weekly')
BARS = 2500           # The number of bars to retrieve
LOOK_BACK_DAYS = 90  # Number of past days to use for prediction
PREDICTION_DAYS = 30 # Not used in this version, but kept for context.
LSTM_UNITS = 32      # Number of units in the LSTM layer
EPOCHS = 20          # Number of training epochs
BATCH_SIZE = 32      # Batch size for training

# %% [markdown]
# 2. Generate Refresh Token

# %%
# generate refresh token

# the login URL into your brower and login with your TradeStation credentials
print(f'https://signin.tradestation.com/authorize?response_type=code&client_id={CLIENT_ID}&audience=https%3A%2F%2Fapi.tradestation.com&redirect_uri=http%3A%2F%2Flocalhost%3A3000&scope=openid%20MarketData%20profile%20ReadAccount%20Trade%20offline_access%20Matrix%20OptionSpreads')

# %%
from urllib.parse import urlparse, parse_qs

# 1. After logging in, your browser will redirect to a URL like: http://localhost:3000/?code=...
# 2. Copy that full URL from your browser's address bar.
# 3. Paste the copied URL here, replacing the placeholder text.
redirected_url = f"https://signin.tradestation.com/authorize?response_type=code&client_id={CLIENT_ID}&audience=https%3A%2F%2Fapi.tradestation.com&redirect_uri=http%3A%2F%2Flocalhost%3A3000&scope=openid%20MarketData%20profile%20ReadAccount%20Trade%20offline_access%20Matrix%20OptionSpreads"
print(redirected_url)


# Parse the URL to extract the query parameters
parsed_url = urlparse(redirected_url)

print(parsed_url)

query_params = parse_qs(parsed_url.query)

print(query_params)

# Extract the 'client_id' from the query parameters. It's stored in a list.
if 'client_id' in query_params:
    CODE = query_params['client_id'][0]
    print(f"Successfully extracted authorization code.")
    # The 'CODE' variable can now be used in the next step.
else:
    print("Error: 'code' not found in the redirected URL. Please check the URL and try again.")
    CODE = ""
# Out:
# https://signin.tradestation.com/authorize?response_type=code&client_id=qnEIw9sTwkIUpKKmB19D2ZvgPRFomBfR&audience=https%3A%2F%2Fapi.tradestation.com&redirect_uri=http%3A%2F%2Flocalhost%3A3000&scope=openid%20MarketData%20profile%20ReadAccount%20Trade%20offline_access%20Matrix%20OptionSpreads
# ParseResult(scheme='https', netloc='signin.tradestation.com', path='/authorize', params='', query='response_type=code&client_id=qnEIw9sTwkIUpKKmB19D2ZvgPRFomBfR&audience=https%3A%2F%2Fapi.tradestation.com&redirect_uri=http%3A%2F%2Flocalhost%3A3000&scope=openid%20MarketData%20profile%20ReadAccount%20Trade%20offline_access%20Matrix%20OptionSpreads', fragment='')
# {'response_type': ['code'], 'client_id': ['qnEIw9sTwkIUpKKmB19D2ZvgPRFomBfR'], 'audience': ['https://api.tradestation.com'], 'redirect_uri': ['http://localhost:3000'], 'scope': ['openid MarketData profile ReadAccount Trade offline_access Matrix OptionSpreads']}
# Successfully extracted authorization code.

# %%
print(f"Authorization Code: {CODE}")

# %%
# 1. After logging in, your browser will redirect to a URL like: http://localhost:3000/?code=...
# 2. Copy that full URL from your browser's address bar.
# 3. Paste the copied URL here, replacing the placeholder text.
redirected_url = f"https://signin.tradestation.com/authorize?response_type=code&client_id={CLIENT_ID}&audience=https%3A%2F%2Fapi.tradestation.com&redirect_uri=http%3A%2F%2Flocalhost%3A3000&scope=openid%20MarketData%20profile%20ReadAccount%20Trade%20offline_access%20Matrix%20OptionSpreads"

# Parse the URL to extract the query parameters
parsed_url = urlparse(redirected_url)
query_params = parse_qs(parsed_url.query)

# Extract the 'client_id' from the query parameters. It's stored in a list.
if 'client_id' in query_params:
    CODE = query_params['client_id'][0]
    print(f"Successfully extracted authorization code.")
    # The 'CODE' variable can now be used in the next step.
else:
    print("Error: 'client_id' not found in the redirected URL. Please check the URL and try again.")
    CODE = ""

print(f"Authorization Code: {CODE}")

# this request will get a new access token and refresh token
# if desired, you can paste the refresh token above and rerun that code block
# then after that, you can simply run the next code block anytime you need a new access token
url = "https://signin.tradestation.com/oauth/token"

payload=f'grant_type=authorization_code&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&code={CODE}&redirect_uri=http%3A%2F%2Flocalhost%3A3000'
headers = {
  'Content-Type': 'application/x-www-form-urlencoded'
}

response = requests.request("POST", url, headers=headers, data=payload)
response_data = response.json()
print(response_data)

REFRESH_TOKEN = response_data['refresh_token']
print(f'Copy the refresh token when printed below to Step 1 and rerun Step1.\n''refresh_token: ', REFRESH_TOKEN)

# %%
# if you have a refresh token already, enter it here
REFRESH_TOKEN = 'InBrnUa-SH9jy9zU-Z-1cRsc7lyP4Mko9gWB5_LAqiuUF'

# %% [markdown]
# 3. Authentication

# %%
# --- Authentication ---
def get_access_token():
    url = "https://signin.tradestation.com/oauth/token"

    payload=f'grant_type=refresh_token&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&refresh_token={REFRESH_TOKEN}'
    headers = {
      'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    response_data = response.json()
    return response_data['access_token']

# %% [markdown]
# 4. Data Fetching

# %%
def fetch_data(symbol: str, unit: str = "daily", interval: int = 1, bars_back: int = 200):

    """
    Fetches intraday minute-level stock data from TradeStation API.
    Default: 5-minute bars, returns up to `bars` most recent records.
    """
    print(f"Connecting to TradeStation and fetching data for {symbol}...{unit} interval {interval}...")
    try:

        bars_url = f"{API_BASE_URL}/marketdata/barcharts/{symbol}?interval={interval}&unit={unit}&barsback={bars_back}"

        headers = {'Authorization': f'Bearer {get_access_token()}'}

        try:
            response = requests.get(bars_url, headers=headers)
            response.raise_for_status()
            data = response.json().get('Bars', [])

            if not data:
                print("No data returned from the API.")
                return pd.DataFrame()

            df = pd.DataFrame(data)

            # Normalize timestamp column name if different casing
            ts_col = None
            for col in ['TimeStamp', 'timestamp', 'Timestamp']:
                if col in df.columns:
                    ts_col = col
                    break

            if ts_col is None:
                raise ValueError("Timestamp column not found in returned data.")

            df['timestamp'] = pd.to_datetime(df[ts_col])
            df.set_index('timestamp', inplace=True)
            df.sort_index(inplace=True)

            # Keep expected OHLCV columns if present
            keep_cols = [c for c in ['Open', 'High', 'Low', 'Close', 'TotalVolume'] if c in df.columns]
            df = df[keep_cols]

            # Ensure numeric types
            if 'Close' in df.columns:
                df['Close'] = pd.to_numeric(df['Close'], errors='coerce')
            if 'TotalVolume' in df.columns:
                df['TotalVolume'] = pd.to_numeric(df['TotalVolume'], errors='coerce')

            # Drop NaNs and rows with zero volume (if volume column exists)
            df.dropna(inplace=True)
            if 'TotalVolume' in df.columns:
                df = df[df['TotalVolume'] > 0]

            # Keep only the most recent `bars` records
            if bars_back and len(df) > bars_back:
                df = df.tail(bars_back)

            print(f"Fetched {len(df)} rows of data for {symbol}.")
            return df

        except requests.exceptions.HTTPError as err:
            print(f"HTTP Error: {err}")
            return pd.DataFrame()
        except Exception as e:
            print(f"An error occurred while fetching minute data: {e}")
            return pd.DataFrame()

    except Exception as e:
        print(f"Error preparing request for TradeStation: {e}")
        return None

# %% [markdown]
# 5. Data Retrieval and Feature Engineering

# %%
def create_features(df):
    """
    Creates several technical indicator features from the raw OHLCV data.
    """
    print("Creating technical indicator features...")
    df = df.sort_index()

    # Simple Moving Averages (SMA)
    df['SMA_5'] = df['Close'].rolling(window=5).mean()
    df['SMA_10'] = df['Close'].rolling(window=10).mean()

    # Relative Strength Index (RSI)
    delta = df['Close'].diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    avg_gain = gain.rolling(window=14).mean()
    avg_loss = loss.rolling(window=14).mean()
    rs = avg_gain / avg_loss
    df['RSI'] = 100 - (100 / (1 + rs))

    # MACD (Moving Average Convergence Divergence)
    exp1 = df['Close'].ewm(span=12, adjust=False).mean()
    exp2 = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = exp1 - exp2

    # Bollinger Bands
    df['Bollinger_High'] = df['Close'].rolling(window=20).mean() + 2 * df['Close'].rolling(window=20).std()
    df['Bollinger_Low'] = df['Close'].rolling(window=20).mean() - 2 * df['Close'].rolling(window=20).std()

    # Volume-based feature
    df['Volume_SMA_5'] = df['TotalVolume'].rolling(window=5).mean()

    # Drop any rows with NaN values created by the rolling windows
    df.dropna(inplace=True)
    
    # Drop rows where volume is 0
    df = df[df['TotalVolume'] > 0]

    #df['ATR'] = np.abs(df['High'] - df['Low']).rolling(window=14).mean()

    print(f"Features created. Shape of data: {df.shape}")
    return df

# %%
stock_data = fetch_data("NVDA", unit="minute", interval=5, bars_back=35000)

print(stock_data)

stock_data = create_features(stock_data)

stock_data.head()
# Out:
# Connecting to TradeStation and fetching data for NVDA...minute interval 5...
# Fetched 35000 rows of data for NVDA.
#                              Open    High     Low   Close  TotalVolume
# timestamp
# 2023-11-28 17:05:00+00:00   48.06   48.12   48.02   48.11      2682020
# 2023-11-28 17:10:00+00:00   48.12   48.12   48.04   48.07      3233880
# 2023-11-28 17:15:00+00:00   48.06   48.18   48.04   48.15      2996560
# 2023-11-28 17:20:00+00:00   48.15   48.17   48.12   48.13      2249230
# 2023-11-28 17:25:00+00:00   48.13   48.15   48.06   48.11      3039550
# ...                           ...     ...     ...     ...          ...
# 2025-09-15 19:40:00+00:00  177.07  177.25  177.06  177.11       878394
# 2025-09-15 19:45:00+00:00  177.11  177.16  176.96  177.11      1140421
# 2025-09-15 19:50:00+00:00  177.11  177.33   177.1  177.31      1471970
# 2025-09-15 19:55:00+00:00  177.31  177.46  177.09  177.38      1642055
# 2025-09-15 20:00:00+00:00  177.38  177.88  177.17  177.78      4279997
#
# [35000 rows x 5 columns]
# Creating technical indicator features...
# Features created. Shape of data: (34981, 12)
#                             Open   High    Low  Close  TotalVolume   SMA_5  \
# timestamp
# 2023-11-28 18:40:00+00:00  47.71  47.74  47.69  47.72      1818110  47.698
# 2023-11-28 18:45:00+00:00  47.72  47.76  47.72  47.72      1863550  47.704
# 2023-11-28 18:50:00+00:00  47.72  47.78  47.71  47.74      1920820  47.718
# 2023-11-28 18:55:00+00:00  47.74  47.75  47.68  47.74      2657600  47.728
# 2023-11-28 19:00:00+00:00  47.73  47.75  47.66  47.72      2423260  47.728
#
#                            SMA_10        RSI      MACD  Bollinger_High  \
# timestamp
# 2023-11-28 18:40:00+00:00  47.758  20.000000 -0.105623       48.235225
# 2023-11-28 18:45:00+00:00  47.738  23.404255 -0.103012       48.209033
# 2023-11-28 18:50:00+00:00  47.723  25.000000 -0.098197       48.185051
# 2023-11-28 18:55:00+00:00  47.717  28.571429 -0.093305       48.138491
# 2023-11-28 19:00:00+00:00  47.709  30.000000 -0.090005       48.089257
#
#                            Bollinger_Low  Volume_SMA_5
# timestamp
# 2023-11-28 18:40:00+00:00      47.559775     2442732.0
# 2023-11-28 18:45:00+00:00      47.546967     2178772.0
# 2023-11-28 18:50:00+00:00      47.537949     2052536.0
# 2023-11-28 18:55:00+00:00      47.543509     2076690.0
# 2023-11-28 19:00:00+00:00      47.551743     2136668.0

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2493 entries, 2015-10-15 20:00:00+00:00 to 2025-09-15 20:00:00+00:00
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            2493 non-null   object
#  1   High            2493 non-null   object
#  2   Low             2493 non-null   object
#  3   Close           2493 non-null   float64
#  4   TotalVolume     2493 non-null   int64
#  5   SMA_5           2493 non-null   float64
#  6   SMA_10          2493 non-null   float64
#  7   RSI             2493 non-null   float64
#  8   MACD            2493 non-null   float64
#  9   Bollinger_High  2493 non-null   float64
#  10  Bollinger_Low   2493 non-null   float64
#  11  Volume_SMA_5    2493 non-null   float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 253.2+ KB

# %%
print(stock_data.describe())
# Out:
#              Close   TotalVolume        SMA_5       SMA_10          RSI  \
# count  2493.000000  2.493000e+03  2493.000000  2493.000000  2493.000000
# mean     30.837164  4.640717e+08    30.695303    30.522831    57.068778
# std      44.420204  2.560081e+08    44.209844    43.967582    17.194558
# min       0.630000  5.244924e+07     0.636000     0.654000     8.216433
# 25%       4.230000  2.990104e+08     4.206000     4.178000    44.528875
# 50%      12.470000  4.132420e+08    12.492000    12.557000    57.936508
# 75%      28.950000  5.639356e+08    28.706000    28.811000    69.634489
# max     183.160000  3.692928e+09   182.306000   181.244000   100.000000
#
#               MACD  Bollinger_High  Bollinger_Low  Volume_SMA_5
# count  2493.000000     2493.000000    2493.000000  2.493000e+03
# mean      0.489084       33.327500      27.020407  4.642957e+08
# std       1.769111       47.719528      39.342714  2.084321e+08
# min      -6.260129        0.696129       0.546871  1.301348e+08
# 25%      -0.026573        4.631179       3.874573  3.192368e+08
# 50%       0.090550       13.629763      11.093951  4.297236e+08
# 75%       0.455188       31.714002      25.938254  5.624469e+08
# max       9.773913      187.556043     174.201525  1.881870e+09

# %%
print(stock_data.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'TotalVolume', 'SMA_5', 'SMA_10', 'RSI',
#        'MACD', 'Bollinger_High', 'Bollinger_Low', 'Volume_SMA_5'],
#       dtype='object')

# %%
stock_data = stock_data[stock_data["Close"].notnull()]

# %% [markdown]
# <div style="background-color: purple; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Prepare the Data
# </div>

# %%
def prepare_data(data, target_column='close', look_back=60):
    """
    Scales the data and creates sequences for LSTM training.
    """
    print("Preparing data for LSTM...")
    # Select features to use
    features = ['Close', 'Open', 'High', 'Low', 'TotalVolume', 'SMA_5', 'SMA_10', 'RSI', 'MACD', 'Bollinger_High', 'Bollinger_Low', 'Volume_SMA_5']
    data = data[features].values

    # Scale the data using MinMaxScaler
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    # Create sequences for LSTM
    X, y = [], []
    for i in range(len(scaled_data) - look_back - 1):
        X.append(scaled_data[i:(i + look_back), :])
        y.append(scaled_data[i + look_back, 0])  # Predict the 'close' price of the next day

    X, y = np.array(X), np.array(y)

    # Split into training and testing sets
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    print(f"Training data shape: {X_train.shape}")
    print(f"Testing data shape: {X_test.shape}")

    return X_train, X_test, y_train, y_test, scaler

# %% [markdown]
# <div style="background-color: purple; color: white; padding: 10px; border-square: 10px; text-align: center; font-size: 24px; font-weight: bold; max-width: 90%; margin: auto;">
#     Build the LSTM Model
# </div>

# %%
def create_lstm_model(input_shape, units=50):
    """
    Builds the LSTM model architecture.
    """
    print("Creating LSTM model...")


    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(units, return_sequences=True, input_shape=input_shape),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(units, return_sequences=False),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(units=1) # Output layer for single value prediction
    ])

    
    model.compile(optimizer='adam', loss='mean_squared_error')

                
    return model

# %%
def create_lstm_model(input_shape, units=50):
    """
    Builds the LSTM model architecture.
    """
    print("Creating LSTM model...")

    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(32),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(units=1) # Output layer for single value prediction
    ])


    # Compile model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mse',
        metrics=['mae']
    )            
    return model

# %%
# --- MAIN EXECUTION ---

# Fetch and prepare the data
df = fetch_data(SYMBOL)
if df is not None and not df.empty:
    df = create_features(df)
    X_train, X_test, y_train, y_test, scaler = prepare_data(df, look_back=LOOK_BACK_DAYS)

    # Build and train the model
    model = create_lstm_model(input_shape=(X_train.shape[1], X_train.shape[2]), units=LSTM_UNITS)
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.1, verbose=1)

    # --- Plotting the Model Performance (Loss) ---
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Training Performance')
    plt.xlabel('Epoch')
    plt.ylabel('Loss (Mean Squared Error)')
    plt.legend()
    plt.grid(True)
    plt.show()

    # --- Plotting the Prediction vs. Actual Prices ---
    print("Making predictions on the test set...")
    # Make predictions
    predictions = model.predict(X_test)

    # Inverse transform the predictions and actual values
    # Need to create a dummy array with the same number of features to inverse transform
    dummy_array = np.zeros((len(predictions), scaler.n_features_in_))
    dummy_array[:, 0] = predictions.flatten()
    predictions = scaler.inverse_transform(dummy_array)[:, 0]

    dummy_array = np.zeros((len(y_test), scaler.n_features_in_))
    dummy_array[:, 0] = y_test.flatten()
    actual_prices = scaler.inverse_transform(dummy_array)[:, 0]

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(actual_prices, predictions))
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

    # Plot the results
    plt.figure(figsize=(14, 7))
    plt.plot(df.index[len(df) - len(actual_prices):], actual_prices, color='blue', label='Actual SPY Price')
    plt.plot(df.index[len(df) - len(predictions):], predictions, color='red', linestyle='--', label='Predicted SPY Price')
    plt.title(f'SPY Price Prediction with LSTM')
    plt.xlabel('Date')
    plt.ylabel('SPY Price (USD)')
    plt.legend()
    plt.grid(True)
    plt.show()

else:
    print("Failed to get data. Exiting.")
# Out:
# Connecting to TradeStation and fetching data for SPY...daily interval 1...
# Fetched 200 rows of data for SPY.
# Creating technical indicator features...
# Features created. Shape of data: (181, 12)
# Preparing data for LSTM...
# Training data shape: (72, 90, 12)
# Testing data shape: (18, 90, 12)
# Creating LSTM model...
# Epoch 1/20
# c:\Users\Afiat_Trading\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - loss: 0.5453 - val_loss: 0.4612
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3009 - val_loss: 0.2042
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1312 - val_loss: 0.0571
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0432 - val_loss: 0.0024
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0222 - val_loss: 0.0114
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0448 - val_loss: 0.0242
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0531 - val_loss: 0.0176
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0386 - val_loss: 0.0050
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0209 - val_loss: 7.9600e-04
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0142 - val_loss: 0.0056
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0111 - val_loss: 0.0148
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0202 - val_loss: 0.0226
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0212 - val_loss: 0.0250
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0141 - val_loss: 0.0229
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0150 - val_loss: 0.0187
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0144 - val_loss: 0.0131
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0128 - val_loss: 0.0079
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0123 - val_loss: 0.0044
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0131 - val_loss: 0.0024
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0156 - val_loss: 0.0018
# Making predictions on the test set...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Root Mean Squared Error (RMSE): 10.1922

# %%
# --- Predicting Future Prices for the Next Day ---

print("Predicting the price for the next day...")

# Get the last sequence from the test set to start the prediction
last_sequence = X_test[-1]
current_sequence = last_sequence.reshape(1, LOOK_BACK_DAYS, X_train.shape[2])

# Predict the next day's scaled closing price
next_day_pred_scaled = model.predict(current_sequence)[0, 0]

# Inverse transform the future prediction
dummy_array_future = np.zeros((1, scaler.n_features_in_))
dummy_array_future[0, 0] = next_day_pred_scaled
next_day_prediction = scaler.inverse_transform(dummy_array_future)[0, 0]

# Generate date for the next day's prediction
last_date = df.index[-1]
next_day_date = last_date + timedelta(days=1)

# --- Plotting the Results with the Next Day's Prediction ---
plt.figure(figsize=(16, 8))

# Plot historical actual prices
plt.plot(df.index[-len(actual_prices):], actual_prices, color='blue', label=f'Actual {SYMBOL} Price')

# Plot historical predicted prices
plt.plot(df.index[-len(predictions):], predictions, color='red', linestyle='--', label=f'Predicted {SYMBOL} Price (Test Set)')

# Plot the next day's predicted price as a point
plt.plot(next_day_date, next_day_prediction, 'go', markersize=10, label=f'Next Day Predicted {SYMBOL} Price')

# Annotate the predicted value on the chart
plt.text(next_day_date, next_day_prediction, f' ${next_day_prediction:.2f}', fontsize=12, verticalalignment='bottom', horizontalalignment='left')


plt.title(f'{SYMBOL} Price Prediction: Historical and Next Day')
plt.xlabel('Date')
plt.ylabel(f'{SYMBOL} Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# Print the future prediction
print(f"\nPredicted Close Price for {next_day_date.date()}: ${next_day_prediction:.2f}")
# Out:
# Predicting the price for the next day...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted Close Price for 2025-09-13: $565.11

# %%
# Create a DataFrame to compare actual and predicted prices
comparison_df = pd.DataFrame({
    'Actual': actual_prices,
    'Predicted': predictions
}, index=df.index[-len(actual_prices):])

# Display the comparison table
print("Comparison of Actual vs. Predicted Prices:")
print(comparison_df.head())

# Display the tail of the comparison table to see the most recent predictions
print("\nMost Recent Predictions:")
print(comparison_df.tail())
# Out:
# Comparison of Actual vs. Predicted Prices:
#                            Actual   Predicted
# timestamp
# 2023-10-12 20:00:00+00:00  436.32  423.099186
# 2023-10-13 20:00:00+00:00  433.66  424.919459
# 2023-10-16 20:00:00+00:00  431.50  426.560376
# 2023-10-17 20:00:00+00:00  436.04  427.636001
# 2023-10-18 20:00:00+00:00  436.02  429.114202
#
# Most Recent Predictions:
#                            Actual   Predicted
# timestamp
# 2025-09-08 20:00:00+00:00  647.24  564.933745
# 2025-09-09 20:00:00+00:00  648.83  564.312253
# 2025-09-10 20:00:00+00:00  650.33  564.203304
# 2025-09-11 20:00:00+00:00  652.21  564.540735
# 2025-09-12 20:00:00+00:00  657.63  565.111346
